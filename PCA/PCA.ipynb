# %% [markdown]
# C = (
#  		1 -2  0
# 	   -2  5  0
#  		0  0  2
# 	)
# => Tim eigenvalue, eigenvector
#
# + Ung dung cong thuc: C.u = λ.u
# => λ goi la eigenvalue voi eigenvector u cua ma tran C
# => Tinh dinh thuc det(C-λI) = 0
#
# det((
#  		1 -2  0
# 	   -2  5  0
#  		0  0  2
# 	)
#
# 	- λ(
# 		1 0 0
# 		0 1 0
# 		0 0 1
# 	   ))
#
# = det((
#  		1 -2  0
# 	   -2  5  0
#  		0  0  2
# 	)
#
# 	- (
# 		λ 0 0
# 		0 λ 0
# 		0 0 λ
# 	   ))
#
# = det((
#  		1-λ -2-0  0-0
# 	   -2-0  5-λ  0-0
#  		0-0  0-0  2-λ
# 	))
#
# = det((
#  		1-λ -2    0
# 	   -2    5-λ  0
#  		0    0    2-λ
# 	))
#
# - Chọn hàng hoặc cột tham chiếu, vd chon hang co C31 = 0, C32=0, C33 = 2-λ
# - Ta co 3 ma tran con la:
# 	D1 =(
# 		-2    0
# 	 	 5-λ  0
# 	)
# 	D2 =(
# 		 1-λ  0
# 	    -2    0
# 	)
# 	D3 =(
# 		 1-λ -2
# 	    -2   5-λ
# 	)
#
# => Định thức = C31|D1| - C32|D2| + C33|D3|
# = 0|D1| - 0|D2| + (2-λ)|D3|
# = (2-λ)|D3|
# = (2-λ)((1-λ)(5-λ) - 4)
# = (2-λ)(λ^2 - 6λ + 1)
# = -λ^3 + 8λ^2 - 13λ + 2
#
# Giai phuong trinh bac 3, co nghiem = 2, 3+2can2, 3-2can2
# Vay eigenvalues = 2, 3+2can2, 3-2can2

# %% [markdown]
# ===> Tinh eigenvector λ = 2
# Tinh (C - λI)
# 	((
#  		1 -2  0
# 	   -2  5  0
#  		0  0  2
# 	)
#
# 	- 2(
# 		1 0 0
# 		0 1 0
# 		0 0 1
# 	   ))
#
# = ((
#  		1 -2  0
# 	   -2  5  0
#  		0  0  2
# 	)
#
# 	- (
# 		2 0 0
# 		0 2 0
# 		0 0 2
# 	   ))
#
# = ((
#  		1 -2  0
# 	   -2  5  0
#  		0  0  2
# 	)
#
# 	- (
# 		2 0 0
# 		0 2 0
# 		0 0 2
# 	   ))
#
# = (
#  		1-2  -2-0  0-0
# 	   -2-0   5-2  0-0
#  		0-0   0-0  2-2
# 	)
# = (
#  		-1  -2  0
# 	    -2   3  0
#  		 0   0  0
# 	)
